# %%
# 📌 EDA Pipeline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Load dataset

# Load Cleveland dataset
col_names = [
    "age", "sex", "cp", "trestbps", "chol", "fbs",
    "restecg", "thalach", "exang", "oldpeak", "slope",
    "ca", "thal", "target"
]

df = pd.read_csv(
    "/kaggle/input/datata/processed.cleveland.data",
    names=col_names
)

print(df.head())

# 2. Basic info
print(df.shape)
print(df.isnull().sum())
print(df.describe())

# 3. Univariate
sns.histplot(df["age"], bins=20, kde=True); plt.show()
sns.countplot(x="sex", data=df); plt.show()

# 4. Bivariate
sns.scatterplot(x="age", y="chol", hue="target", data=df); plt.show()
sns.boxplot(x="target", y="thalach", data=df); plt.show()

# 5. Correlation Heatmap
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm"); plt.show()

# 6. Multivariate
sns.pairplot(df[["age","chol","thalach","target"]], hue="target"); plt.show()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca thal  target
# 0    3.0  0.0  6.0       0
# 1    2.0  3.0  3.0       2
# 2    2.0  2.0  7.0       1
# 3    3.0  0.0  3.0       0
# 4    1.0  0.0  3.0       0
# (303, 14)
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64
#               age         sex          cp    trestbps        chol         fbs  \
# ...

# %%
# 📌 Enhanced EDA Pipeline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Load dataset
col_names = [
    "age", "sex", "cp", "trestbps", "chol", "fbs",
    "restecg", "thalach", "exang", "oldpeak", "slope",
    "ca", "thal", "target"
]

df = pd.read_csv(
    "/kaggle/input/datata/processed.cleveland.data",
    names=col_names
)

# Replace "?" with NaN and convert to numeric where needed
df = df.replace("?", pd.NA)
df = df.apply(pd.to_numeric, errors="ignore")

print("✅ Data Loaded")
print(df.head(), "\n")

# 2. Basic info
print("Shape:", df.shape)
print("\nMissing values:\n", df.isnull().sum())
print("\nSummary statistics:\n", df.describe(include="all"))

# 3. Univariate Analysis
plt.figure(figsize=(6,4))
sns.histplot(df["age"].dropna(), bins=20, kde=True)
plt.title("Age Distribution")
plt.tight_layout()
plt.show()

plt.figure(figsize=(6,4))
sns.countplot(x="sex", data=df)
plt.title("Sex Distribution (0=Female, 1=Male)")
plt.tight_layout()
plt.show()

plt.figure(figsize=(6,4))
sns.countplot(x="cp", data=df)
plt.title("Chest Pain Types")
plt.tight_layout()
plt.show()

# 4. Bivariate Analysis
plt.figure(figsize=(6,4))
sns.scatterplot(x="age", y="chol", hue="target", data=df, palette="Set1")
plt.title("Cholesterol vs Age (by Target)")
plt.tight_layout()
plt.show()

plt.figure(figsize=(6,4))
sns.boxplot(x="target", y="thalach", data=df, palette="Set2")
plt.title("Max Heart Rate by Target")
plt.tight_layout()
plt.show()

# 5. Correlation Heatmap
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# 6. Multivariate
sns.pairplot(df[["age","chol","thalach","target"]].dropna(), hue="target", diag_kind="kde", palette="husl")
plt.suptitle("Pairplot of Key Features", y=1.02)
plt.show()
# Out:
# /tmp/ipykernel_36/2524770481.py:20: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors="ignore")
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ✅ Data Loaded
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
# ...
